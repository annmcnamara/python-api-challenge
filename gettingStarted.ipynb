# %% [markdown]
# ##### Visualizing the weather of 500+ cities across the world of varying distance from the equator.

# %%
#import 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests
import json

from citipy import citipy

city = citipy.nearest_city(53.2707,-9.0568)
print(city.city_name)

city = citipy.nearest_city(29.7604,-95.3698)
print(city.city_name)
# Out:
# galway
# houston

# %% [markdown]
# #### Request API Connection

# %%
#open weather key
api_key = "283a9319d8bc008a581bb0b88d702293"
api_key
# Out:
# '283a9319d8bc008a581bb0b88d702293'

# %%
url="https://history.openweathermap.org/data/2.5/aggregated/year?id=2643743&"+api_key
url= "https://api.openweathermap.org/data/2.5/forecast?id=524901&APPID="+api_key

# %%
# Print the response object to the console
print(url)
print(requests.get(url))
# Out:
# https://api.openweathermap.org/data/2.5/forecast?id=524901&APPID=283a9319d8bc008a581bb0b88d702293
# <Response [200]>

# %%
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "city": {
#         "coord": {
#             "lat": 55.7522,
#             "lon": 37.6156
#         },
#         "country": "RU",
#         "id": 524901,
#         "name": "Moscow",
#         "sunrise": 1583726393,
#         "sunset": 1583767223,
#         "timezone": 10800
#     },
#     "cnt": 40,
#     "cod": "200",
#     "list": [
#         {
#             "clouds": {
#                 "all": 97
#             },
#             "dt": 1583787600,
#             "dt_txt": "2020-03-09 21:00:00",
#             "main": {
#                 "feels_like": 276,
#                 "grnd_level": 997,
#                 "humidity": 85,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 279.07,
#                 "temp_kf": 2.78,
#                 "temp_max": 279.07,
#                 "temp_min": 276.29
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 151,
#                 "speed": 2.39
#             }
#         },
#         {
#             "clouds": {
#                 "all": 98
#             },
#             "dt": 1583798400,
#             "dt_txt": "2020-03-10 00:00:00",
#             "main": {
#                 "feels_like": 275.81,
#                 "grnd_level": 995,
#                 "humidity": 93,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "temp": 278.63,
#                 "temp_kf": 2.09,
#                 "temp_max": 278.63,
#                 "temp_min": 276.54
#             },
#             "rain": {
#                 "3h": 0.63
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 121,
#                 "speed": 2.27
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583809200,
#             "dt_txt": "2020-03-10 03:00:00",
#             "main": {
#                 "feels_like": 274.75,
#                 "grnd_level": 993,
#                 "humidity": 98,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "temp": 277.96,
#                 "temp_kf": 1.39,
#                 "temp_max": 277.96,
#                 "temp_min": 276.57
#             },
#             "rain": {
#                 "3h": 3.94
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "moderate rain",
#                     "icon": "10n",
#                     "id": 501,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 97,
#                 "speed": 2.84
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583820000,
#             "dt_txt": "2020-03-10 06:00:00",
#             "main": {
#                 "feels_like": 275.7,
#                 "grnd_level": 991,
#                 "humidity": 99,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "temp": 277.9,
#                 "temp_kf": 0.7,
#                 "temp_max": 277.9,
#                 "temp_min": 277.2
#             },
#             "rain": {
#                 "3h": 5
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "moderate rain",
#                     "icon": "10d",
#                     "id": 501,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 161,
#                 "speed": 1.43
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583830800,
#             "dt_txt": "2020-03-10 09:00:00",
#             "main": {
#                 "feels_like": 275.88,
#                 "grnd_level": 990,
#                 "humidity": 96,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "temp": 279.43,
#                 "temp_kf": 0,
#                 "temp_max": 279.43,
#                 "temp_min": 279.43
#             },
#             "rain": {
#                 "3h": 1.56
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 240,
#                 "speed": 3.66
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583841600,
#             "dt_txt": "2020-03-10 12:00:00",
#             "main": {
#                 "feels_like": 276.91,
#                 "grnd_level": 991,
#                 "humidity": 88,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "temp": 280.1,
#                 "temp_kf": 0,
#                 "temp_max": 280.1,
#                 "temp_min": 280.1
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 296,
#                 "speed": 2.98
#             }
#         },
#         {
#             "clouds": {
#                 "all": 46
#             },
#             "dt": 1583852400,
#             "dt_txt": "2020-03-10 15:00:00",
#             "main": {
#                 "feels_like": 275.98,
#                 "grnd_level": 991,
#                 "humidity": 91,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "temp": 278.41,
#                 "temp_kf": 0,
#                 "temp_max": 278.41,
#                 "temp_min": 278.41
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 9,
#                 "speed": 1.57
#             }
#         },
#         {
#             "clouds": {
#                 "all": 63
#             },
#             "dt": 1583863200,
#             "dt_txt": "2020-03-10 18:00:00",
#             "main": {
#                 "feels_like": 275.3,
#                 "grnd_level": 992,
#                 "humidity": 93,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "temp": 277.12,
#                 "temp_kf": 0,
#                 "temp_max": 277.12,
#                 "temp_min": 277.12
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 25,
#                 "speed": 0.44
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583874000,
#             "dt_txt": "2020-03-10 21:00:00",
#             "main": {
#                 "feels_like": 275.19,
#                 "grnd_level": 991,
#                 "humidity": 94,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "temp": 277.1,
#                 "temp_kf": 0,
#                 "temp_max": 277.1,
#                 "temp_min": 277.1
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 35,
#                 "speed": 0.6
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583884800,
#             "dt_txt": "2020-03-11 00:00:00",
#             "main": {
#                 "feels_like": 274.93,
#                 "grnd_level": 990,
#                 "humidity": 94,
#                 "pressure": 1010,
#                 "sea_level": 1010,
#                 "temp": 277.19,
#                 "temp_kf": 0,
#                 "temp_max": 277.19,
#                 "temp_min": 277.19
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 111,
#                 "speed": 1.12
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583895600,
#             "dt_txt": "2020-03-11 03:00:00",
#             "main": {
#                 "feels_like": 274.51,
#                 "grnd_level": 988,
#                 "humidity": 95,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "temp": 276.85,
#                 "temp_kf": 0,
#                 "temp_max": 276.85,
#                 "temp_min": 276.85
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 143,
#                 "speed": 1.19
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583906400,
#             "dt_txt": "2020-03-11 06:00:00",
#             "main": {
#                 "feels_like": 275.77,
#                 "grnd_level": 986,
#                 "humidity": 93,
#                 "pressure": 1007,
#                 "sea_level": 1007,
#                 "temp": 278.1,
#                 "temp_kf": 0,
#                 "temp_max": 278.1,
#                 "temp_min": 278.1
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 166,
#                 "speed": 1.42
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583917200,
#             "dt_txt": "2020-03-11 09:00:00",
#             "main": {
#                 "feels_like": 278.57,
#                 "grnd_level": 984,
#                 "humidity": 77,
#                 "pressure": 1004,
#                 "sea_level": 1004,
#                 "temp": 281.18,
#                 "temp_kf": 0,
#                 "temp_max": 281.18,
#                 "temp_min": 281.18
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 183,
#                 "speed": 1.91
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583928000,
#             "dt_txt": "2020-03-11 12:00:00",
#             "main": {
#                 "feels_like": 278.02,
#                 "grnd_level": 981,
#                 "humidity": 83,
#                 "pressure": 1001,
#                 "sea_level": 1001,
#                 "temp": 281.2,
#                 "temp_kf": 0,
#                 "temp_max": 281.2,
#                 "temp_min": 281.2
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 174,
#                 "speed": 3.03
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583938800,
#             "dt_txt": "2020-03-11 15:00:00",
#             "main": {
#                 "feels_like": 277.12,
#                 "grnd_level": 979,
#                 "humidity": 92,
#                 "pressure": 999,
#                 "sea_level": 999,
#                 "temp": 280.21,
#                 "temp_kf": 0,
#                 "temp_max": 280.21,
#                 "temp_min": 280.21
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 195,
#                 "speed": 3.06
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583949600,
#             "dt_txt": "2020-03-11 18:00:00",
#             "main": {
#                 "feels_like": 275.68,
#                 "grnd_level": 977,
#                 "humidity": 83,
#                 "pressure": 998,
#                 "sea_level": 998,
#                 "temp": 279.7,
#                 "temp_kf": 0,
#                 "temp_max": 279.7,
#                 "temp_min": 279.7
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 222,
#                 "speed": 3.83
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583960400,
#             "dt_txt": "2020-03-11 21:00:00",
#             "main": {
#                 "feels_like": 273.91,
#                 "grnd_level": 976,
#                 "humidity": 91,
#                 "pressure": 997,
#                 "sea_level": 997,
#                 "temp": 278.3,
#                 "temp_kf": 0,
#                 "temp_max": 278.3,
#                 "temp_min": 278.3
#             },
#             "rain": {
#                 "3h": 0.25
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 224,
#                 "speed": 4.33
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583971200,
#             "dt_txt": "2020-03-12 00:00:00",
#             "main": {
#                 "feels_like": 273.77,
#                 "grnd_level": 975,
#                 "humidity": 92,
#                 "pressure": 996,
#                 "sea_level": 996,
#                 "temp": 278.4,
#                 "temp_kf": 0,
#                 "temp_max": 278.4,
#                 "temp_min": 278.4
#             },
#             "rain": {
#                 "3h": 1.56
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 277,
#                 "speed": 4.75
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1583982000,
#             "dt_txt": "2020-03-12 03:00:00",
#             "main": {
#                 "feels_like": 270.63,
#                 "grnd_level": 977,
#                 "humidity": 80,
#                 "pressure": 998,
#                 "sea_level": 998,
#                 "temp": 276.63,
#                 "temp_kf": 0,
#                 "temp_max": 276.63,
#                 "temp_min": 276.63
#             },
#             "rain": {
#                 "3h": 0.19
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 280,
#                 "speed": 5.81
#             }
#         },
#         {
#             "clouds": {
#                 "all": 63
#             },
#             "dt": 1583992800,
#             "dt_txt": "2020-03-12 06:00:00",
#             "main": {
#                 "feels_like": 269.08,
#                 "grnd_level": 979,
#                 "humidity": 73,
#                 "pressure": 1000,
#                 "sea_level": 1000,
#                 "temp": 276.59,
#                 "temp_kf": 0,
#                 "temp_max": 276.59,
#                 "temp_min": 276.59
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 277,
#                 "speed": 7.7
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1584003600,
#             "dt_txt": "2020-03-12 09:00:00",
#             "main": {
#                 "feels_like": 270.56,
#                 "grnd_level": 980,
#                 "humidity": 66,
#                 "pressure": 1001,
#                 "sea_level": 1001,
#                 "temp": 277.99,
#                 "temp_kf": 0,
#                 "temp_max": 277.99,
#                 "temp_min": 277.99
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 271,
#                 "speed": 7.58
#             }
#         },
#         {
#             "clouds": {
#                 "all": 77
#             },
#             "dt": 1584014400,
#             "dt_txt": "2020-03-12 12:00:00",
#             "main": {
#                 "feels_like": 272.55,
#                 "grnd_level": 980,
#                 "humidity": 57,
#                 "pressure": 1001,
#                 "sea_level": 1001,
#                 "temp": 280.21,
#                 "temp_kf": 0,
#                 "temp_max": 280.21,
#                 "temp_min": 280.21
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 254,
#                 "speed": 7.93
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1584025200,
#             "dt_txt": "2020-03-12 15:00:00",
#             "main": {
#                 "feels_like": 271.81,
#                 "grnd_level": 979,
#                 "humidity": 61,
#                 "pressure": 1000,
#                 "sea_level": 1000,
#                 "temp": 278.81,
#                 "temp_kf": 0,
#                 "temp_max": 278.81,
#                 "temp_min": 278.81
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 247,
#                 "speed": 6.91
#             }
#         },
#         {
#             "clouds": {
#                 "all": 48
#             },
#             "dt": 1584036000,
#             "dt_txt": "2020-03-12 18:00:00",
#             "main": {
#                 "feels_like": 271.45,
#                 "grnd_level": 978,
#                 "humidity": 70,
#                 "pressure": 999,
#                 "sea_level": 999,
#                 "temp": 278.3,
#                 "temp_kf": 0,
#                 "temp_max": 278.3,
#                 "temp_min": 278.3
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 232,
#                 "speed": 6.98
#             }
#         },
#         {
#             "clouds": {
#                 "all": 85
#             },
#             "dt": 1584046800,
#             "dt_txt": "2020-03-12 21:00:00",
#             "main": {
#                 "feels_like": 273.01,
#                 "grnd_level": 976,
#                 "humidity": 81,
#                 "pressure": 996,
#                 "sea_level": 996,
#                 "temp": 278.78,
#                 "temp_kf": 0,
#                 "temp_max": 278.78,
#                 "temp_min": 278.78
#             },
#             "rain": {
#                 "3h": 0.13
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 232,
#                 "speed": 6.01
#             }
#         },
#         {
#             "clouds": {
#                 "all": 92
#             },
#             "dt": 1584057600,
#             "dt_txt": "2020-03-13 00:00:00",
#             "main": {
#                 "feels_like": 272.31,
#                 "grnd_level": 973,
#                 "humidity": 82,
#                 "pressure": 994,
#                 "sea_level": 994,
#                 "temp": 279.6,
#                 "temp_kf": 0,
#                 "temp_max": 279.6,
#                 "temp_min": 279.6
#             },
#             "rain": {
#                 "3h": 0.44
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 246,
#                 "speed": 8.42
#             }
#         },
#         {
#             "clouds": {
#                 "all": 67
#             },
#             "dt": 1584068400,
#             "dt_txt": "2020-03-13 03:00:00",
#             "main": {
#                 "feels_like": 268.97,
#                 "grnd_level": 974,
#                 "humidity": 59,
#                 "pressure": 995,
#                 "sea_level": 995,
#                 "temp": 276.93,
#                 "temp_kf": 0,
#                 "temp_max": 276.93,
#                 "temp_min": 276.93
#             },
#             "snow": {
#                 "3h": 1.75
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "snow",
#                     "icon": "13n",
#                     "id": 601,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 259,
#                 "speed": 7.88
#             }
#         },
#         {
#             "clouds": {
#                 "all": 43
#             },
#             "dt": 1584079200,
#             "dt_txt": "2020-03-13 06:00:00",
#             "main": {
#                 "feels_like": 266.39,
#                 "grnd_level": 975,
#                 "humidity": 54,
#                 "pressure": 996,
#                 "sea_level": 996,
#                 "temp": 276.2,
#                 "temp_kf": 0,
#                 "temp_max": 276.2,
#                 "temp_min": 276.2
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 260,
#                 "speed": 10.24
#             }
#         },
#         {
#             "clouds": {
#                 "all": 67
#             },
#             "dt": 1584090000,
#             "dt_txt": "2020-03-13 09:00:00",
#             "main": {
#                 "feels_like": 267.55,
#                 "grnd_level": 976,
#                 "humidity": 54,
#                 "pressure": 996,
#                 "sea_level": 996,
#                 "temp": 277.74,
#                 "temp_kf": 0,
#                 "temp_max": 277.74,
#                 "temp_min": 277.74
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 264,
#                 "speed": 11
#             }
#         },
#         {
#             "clouds": {
#                 "all": 79
#             },
#             "dt": 1584100800,
#             "dt_txt": "2020-03-13 12:00:00",
#             "main": {
#                 "feels_like": 269.3,
#                 "grnd_level": 977,
#                 "humidity": 46,
#                 "pressure": 998,
#                 "sea_level": 998,
#                 "temp": 279.07,
#                 "temp_kf": 0,
#                 "temp_max": 279.07,
#                 "temp_min": 279.07
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 269,
#                 "speed": 10.26
#             }
#         },
#         {
#             "clouds": {
#                 "all": 74
#             },
#             "dt": 1584111600,
#             "dt_txt": "2020-03-13 15:00:00",
#             "main": {
#                 "feels_like": 269.89,
#                 "grnd_level": 978,
#                 "humidity": 57,
#                 "pressure": 999,
#                 "sea_level": 999,
#                 "temp": 277.13,
#                 "temp_kf": 0,
#                 "temp_max": 277.13,
#                 "temp_min": 277.13
#             },
#             "snow": {
#                 "3h": 0.13
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13d",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 266,
#                 "speed": 6.81
#             }
#         },
#         {
#             "clouds": {
#                 "all": 40
#             },
#             "dt": 1584122400,
#             "dt_txt": "2020-03-13 18:00:00",
#             "main": {
#                 "feels_like": 268.53,
#                 "grnd_level": 980,
#                 "humidity": 65,
#                 "pressure": 1001,
#                 "sea_level": 1001,
#                 "temp": 275.63,
#                 "temp_kf": 0,
#                 "temp_max": 275.63,
#                 "temp_min": 275.63
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 259,
#                 "speed": 6.66
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1584133200,
#             "dt_txt": "2020-03-13 21:00:00",
#             "main": {
#                 "feels_like": 268.03,
#                 "grnd_level": 981,
#                 "humidity": 72,
#                 "pressure": 1002,
#                 "sea_level": 1002,
#                 "temp": 275.03,
#                 "temp_kf": 0,
#                 "temp_max": 275.03,
#                 "temp_min": 275.03
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 262,
#                 "speed": 6.66
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1584144000,
#             "dt_txt": "2020-03-14 00:00:00",
#             "main": {
#                 "feels_like": 266.68,
#                 "grnd_level": 984,
#                 "humidity": 68,
#                 "pressure": 1005,
#                 "sea_level": 1005,
#                 "temp": 273.17,
#                 "temp_kf": 0,
#                 "temp_max": 273.17,
#                 "temp_min": 273.17
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 279,
#                 "speed": 5.51
#             }
#         },
#         {
#             "clouds": {
#                 "all": 67
#             },
#             "dt": 1584154800,
#             "dt_txt": "2020-03-14 03:00:00",
#             "main": {
#                 "feels_like": 265.39,
#                 "grnd_level": 986,
#                 "humidity": 64,
#                 "pressure": 1007,
#                 "sea_level": 1007,
#                 "temp": 271.95,
#                 "temp_kf": 0,
#                 "temp_max": 271.95,
#                 "temp_min": 271.95
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 276,
#                 "speed": 5.35
#             }
#         },
#         {
#             "clouds": {
#                 "all": 78
#             },
#             "dt": 1584165600,
#             "dt_txt": "2020-03-14 06:00:00",
#             "main": {
#                 "feels_like": 264.95,
#                 "grnd_level": 987,
#                 "humidity": 53,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "temp": 272.2,
#                 "temp_kf": 0,
#                 "temp_max": 272.2,
#                 "temp_min": 272.2
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 295,
#                 "speed": 6.06
#             }
#         },
#         {
#             "clouds": {
#                 "all": 58
#             },
#             "dt": 1584176400,
#             "dt_txt": "2020-03-14 09:00:00",
#             "main": {
#                 "feels_like": 265.93,
#                 "grnd_level": 989,
#                 "humidity": 41,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "temp": 273.29,
#                 "temp_kf": 0,
#                 "temp_max": 273.29,
#                 "temp_min": 273.29
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 301,
#                 "speed": 5.99
#             }
#         },
#         {
#             "clouds": {
#                 "all": 39
#             },
#             "dt": 1584187200,
#             "dt_txt": "2020-03-14 12:00:00",
#             "main": {
#                 "feels_like": 265.32,
#                 "grnd_level": 990,
#                 "humidity": 38,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "temp": 273.1,
#                 "temp_kf": 0,
#                 "temp_max": 273.1,
#                 "temp_min": 273.1
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 313,
#                 "speed": 6.49
#             }
#         },
#         {
#             "clouds": {
#                 "all": 40
#             },
#             "dt": 1584198000,
#             "dt_txt": "2020-03-14 15:00:00",
#             "main": {
#                 "feels_like": 263.9,
#                 "grnd_level": 992,
#                 "humidity": 36,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "temp": 271.1,
#                 "temp_kf": 0,
#                 "temp_max": 271.1,
#                 "temp_min": 271.1
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 326,
#                 "speed": 5.46
#             }
#         },
#         {
#             "clouds": {
#                 "all": 20
#             },
#             "dt": 1584208800,
#             "dt_txt": "2020-03-14 18:00:00",
#             "main": {
#                 "feels_like": 262.61,
#                 "grnd_level": 995,
#                 "humidity": 34,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "temp": 269.9,
#                 "temp_kf": 0,
#                 "temp_max": 269.9,
#                 "temp_min": 269.9
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 333,
#                 "speed": 5.47
#             }
#         }
#     ],
#     "message": 0
# }

# %%
response = requests.get(url).json()
type(response)
response['city']
response.keys()

lat = response['city']['coord']['lat']
lon = response['city']['coord']['lon']
print(lat,lon)
# Out:
# 55.7522 37.6156

# %% [markdown]
# #### Build a series of scatter plots to showcase the following relationships:
#
# 1. Temperature (F) vs. Latitude
# 2. Humidity (%) vs. Latitude
# 3. Cloudiness (%) vs. Latitude
# 4. Wind Speed (mph) vs. Latitude
#
# After each plot add a sentence or too explaining what the code is and analyzing.

# %% [markdown]
# #### Run linear regression on each relationship,
# Ths time separating them into Northern Hemisphere (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude):
#
# * Northern Hemisphere - Temperature (F) vs. Latitude
# * Southern Hemisphere - Temperature (F) vs. Latitude
# * Northern Hemisphere - Humidity (%) vs. Latitude
# * Southern Hemisphere - Humidity (%) vs. Latitude
# * Northern Hemisphere - Cloudiness (%) vs. Latitude
# * Southern Hemisphere - Cloudiness (%) vs. Latitude
# * Northern Hemisphere - Wind Speed (mph) vs. Latitude
# * Southern Hemisphere - Wind Speed (mph) vs. Latitude
#
# After each pair of plots explain what the linear regression is modelling such as any relationships you notice and any other analysis you may have.

# %% [markdown]
# #### This notebook:
#
# * Randomly selects at least 500 unique (non-repeat) cities based on latitude and longitude.
# * Performs a weather check on each of the cities using a series of successive API calls.
# * Includes a print log of each city as it's being processed with the city number and city name.
# * Saves a CSV of all retrieved data and a PNG image for each scatter plot.
